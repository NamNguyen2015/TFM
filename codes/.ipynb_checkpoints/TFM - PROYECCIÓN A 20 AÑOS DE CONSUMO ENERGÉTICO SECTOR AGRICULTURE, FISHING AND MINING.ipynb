# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
#load the file
file_path = 'C:/Users/elsad/Downloads/Brazil_Energy balance matrix_cleaned.xlsx'

Dict = pd.read_excel(file_path, sheet_name=None)

print(Dict.keys())

df_2021=Dict['2021']
df_2021 = df_2021.drop(columns=['Unnamed: 0'])
df_2021
# Out:
# dict_keys(['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'])
#                                         SECTOR        OIL  NATURAL GAS
# 0                                   PRODUCTION  152713.43     26371.48  \
# 1                                       IMPORT    7359.21     14796.23
# 2                                       EXPORT   65724.07          NaN
# 3                                 STOCK CHANGE   -1007.78     -3598.93
# 4                                       UNUSED        NaN      1217.87
# 5                                 TOTAL SUPPLY   93340.78     36350.92
# ...

# %%
df_2021.columns
# Out:
# Index(['SECTOR', 'OIL', 'NATURAL GAS', 'COAL', 'HYDROENERGY', 'GEOTHERMAL',
#        'NUCLEAR', 'FIREWOOD', 'SUGARCANE AND PRODUCTS', 'OTHER PRIMARY',
#        'TOTAL PRIMARIES', 'ELECTRICITY', 'LPG', 'GASOLINE/ALCOHOL',
#        'KEROSENE/JET FUEL', 'DIESEL OIL', 'FUEL OIL', 'COKE', 'CHARCOAL',
#        'GASES', 'OTHER SECONDARY', 'NON-ENERGY', 'TOTAL SECUNDARIES', 'TOTAL',
#        'Year'],
#       dtype='object')

# %%
Dict2=Dict.copy()

for k in Dict2.keys():
   # selected_columns = ['SECTOR', 'OIL', 'NATURAL GAS', 'COAL', 'HYDROENERGY', 'GEOTHERMAL',
    #   'NUCLEAR', 'FIREWOOD', 'SUGARCANE AND PRODUCTS', 'OTHER PRIMARY', 'TOTAL PRIMARIES','Year']
    selected_columns = ['SECTOR','TOTAL','Year']
    Dict2[k]=Dict2[k][selected_columns]
    selected_rows=['OWN CONSUMPTION',
       'LOSSES', 'ADJUSTMENT', '   TRANSPORT ', '   INDUSTRIAL',
       '   RESIDENTIAL', '   COMMERCIAL, SERVICES, PUBLIC',
       '   AGRICULTURE, FISHING AND MINING', '   CONSTRUCTION AND OTHERS',
       'ENERGY CONSUMPTION', 'NON-ENERGY CONSUMPTION',
       'FINAL CONSUMPTION']
    Dict2[k]=Dict2[k][Dict2[k]['SECTOR'].isin(selected_rows)]
    
    # Concatenate all DataFrames in Dict vertically
    df_conc = pd.concat(Dict2.values(), ignore_index=True)
    
    # Move the column "Year" to the first position
    last_column_name = df_conc.columns[-1]
    # Reorder the columns by concatenating the last column with the rest of the DataFrame
    df_conc = pd.concat([df_conc[last_column_name], df_conc.drop(columns=last_column_name)], axis=1) # Datafames of TOTAL SUPPLY
    df_conc.set_index("Year", inplace=True)
    df_conc.index = df_conc.index.astype(int)
    #df_TC1=df_conc.drop(columns="SECTOR")
    # Set the value "NaN" by Zero
    df_TC1 = df_conc.apply(lambda column: column.fillna(0))
    
# Calculate the percentage of each product relative to 'TOTAL PRIMARIES'
#percentage_columns_2 = ['ELECTRICITY', 'LPG', 'GASOLINE/ALCOHOL', 'KEROSENE/JET FUEL',
 #      'DIESEL OIL', 'FUEL OIL', 'COKE', 'CHARCOAL', 'GASES',
  #     'OTHER SECONDARY', 'NON-ENERGY']
#percentage_columns_2= ['TOTAL PRIMARIES', 'TOTAL SECUNDARIES']

#df_TC1_percentages = (df_TC1[percentage_columns_2].div(df_TC1['TOTAL'], axis=0) * 100).applymap(lambda x: round(x, 2) if isinstance(x, (int, float)) else x)
df_TC1
# Out:
#                                   SECTOR      TOTAL
# Year
# 1970                     OWN CONSUMPTION    1554.76
# 1970                              LOSSES     929.20
# 1970                          ADJUSTMENT       1.85
# 1970                          TRANSPORT    12661.99
# 1970                          INDUSTRIAL   16020.92
# ...                                  ...        ...
# 2021     AGRICULTURE, FISHING AND MINING   15421.69
# 2021             CONSTRUCTION AND OTHERS       0.00
# 2021                  ENERGY CONSUMPTION  223957.54
# 2021              NON-ENERGY CONSUMPTION   13236.97
# 2021                   FINAL CONSUMPTION  237194.52
#
# [624 rows x 2 columns]

# %%
# Group by Year and SECTOR, and sum the TOTAL values
grouped_df = df_TC1.groupby(['Year', 'SECTOR'])['TOTAL'].sum().reset_index()

# Pivot the data
pivot_df = grouped_df.pivot(index='Year', columns='SECTOR', values='TOTAL')


# Display the result
pivot_df
# Out:
# SECTOR     AGRICULTURE, FISHING AND MINING     COMMERCIAL, SERVICES, PUBLIC
# Year
# 1970                               5351.01                          1266.80  \
# 1971                               5317.39                          1406.98
# 1972                               5338.47                          1570.69
# 1973                               5441.91                          1737.84
# 1974                               5376.38                          1873.46
# 1975                               5348.72                          2059.01
# 1976                               5426.90                          2205.41
# 1977                               5500.89                          2310.21
# 1978                               5372.79                          2479.49
# 1979                               5565.33                          2685.03
# 1980                               5752.24                          2952.03
# ...

# %%
# Dataframe Energy Consumption (EC)
df_EC=pivot_df.drop(columns=['   COMMERCIAL, SERVICES, PUBLIC','   CONSTRUCTION AND OTHERS','   INDUSTRIAL','   RESIDENTIAL' ,'   TRANSPORT ','LOSSES','OWN CONSUMPTION','ADJUSTMENT','ENERGY CONSUMPTION','NON-ENERGY CONSUMPTION'])
df_EC.head()
# Out:
# SECTOR     AGRICULTURE, FISHING AND MINING  FINAL CONSUMPTION
# Year
# 1970                               5351.01           58834.12
# 1971                               5317.39           61691.69
# 1972                               5338.47           65995.12
# 1973                               5441.91           71692.86
# 1974                               5376.38           76198.40

# %%
# Drop the 'FINAL CONSUMPTION' column and calculate the percentages
df_percentages = (df_EC.drop(columns=['FINAL CONSUMPTION']).div(df_EC['FINAL CONSUMPTION'], axis=0) * 100)
df_percentages = df_percentages.round(2)

df_percentages.head()
# Out:
# SECTOR     AGRICULTURE, FISHING AND MINING
# Year
# 1970                                  9.10
# 1971                                  8.62
# 1972                                  8.09
# 1973                                  7.59
# 1974                                  7.06

# %%
# Drop the 'TOTAL PRIMARIES' column (if not already dropped) as it is not needed for the stack plot
df_stackplot = df_EC.drop(columns=["FINAL CONSUMPTION"])

# Plot both stack plots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))


df_stackplot.plot.area(stacked=True, alpha=0.7, ax=ax1)
ax1.set_xlabel('Year')
ax1.set_ylabel('Final Consumption')
ax1.set_title('Energy Consumption Over the Years')
ax1.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0))

df_percentages.plot.area(stacked=True, alpha=0.7, ax=ax2)

ax2.set_xlabel('Year')
ax2.set_ylabel(' Final Consumption  (%)')
ax2.set_title('Percentage of  Energy Consumption Over the Years')
ax2.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0))

plt.tight_layout()
plt.show()

# %%
df_projection = df_stackplot

# Extract the years and values for the '   AGRICULTURE, FISHING AND MINING' sector
years = df_projection.index.values
values = df_projection['   AGRICULTURE, FISHING AND MINING'].values

# Reshape the years array to a 2D array for scikit-learn
years_2d = years.reshape(-1, 1)

# Create a LinearRegression model
model = LinearRegression()

# Fit the model to the data
model.fit(years_2d, values)

# Predict values for the existing years
predicted_values = model.predict(years_2d)

# Predict values for the next 20 years
future_years = np.arange(years[-1] + 1, years[-1] + 21).reshape(-1, 1)
future_predicted_values = model.predict(future_years)

# Print the predicted values for the next 20 years
for year, value in zip(future_years.flatten(), future_predicted_values):
    print(f"Year {year}: Predicted Value {value:.2f}")
# Out:
# Year 2022: Predicted Value 14813.88
# Year 2023: Predicted Value 15037.59
# Year 2024: Predicted Value 15261.30
# Year 2025: Predicted Value 15485.01
# Year 2026: Predicted Value 15708.72
# Year 2027: Predicted Value 15932.43
# Year 2028: Predicted Value 16156.14
# Year 2029: Predicted Value 16379.85
# Year 2030: Predicted Value 16603.56
# Year 2031: Predicted Value 16827.27
# Year 2032: Predicted Value 17050.98
# Year 2033: Predicted Value 17274.68
# Year 2034: Predicted Value 17498.39
# Year 2035: Predicted Value 17722.10
# Year 2036: Predicted Value 17945.81
# Year 2037: Predicted Value 18169.52
# Year 2038: Predicted Value 18393.23
# Year 2039: Predicted Value 18616.94
# Year 2040: Predicted Value 18840.65
# Year 2041: Predicted Value 19064.36

# %%
# Predict values for the existing years
predicted_values = model.predict(years_2d)

# Predict values for the next 20 years
future_years = np.arange(years[-1] + 1, years[-1] + 21).reshape(-1, 1)
future_predicted_values = model.predict(future_years)

# Create a linear plot
plt.figure(figsize=(10, 6))

# Plot actual data
plt.plot(years, values, label='Actual Data', marker='o')

# Plot predicted data for existing years
plt.plot(years, predicted_values, label='Predicted Data (Existing Years)', marker='x')

# Plot predicted data for future years
plt.plot(future_years, future_predicted_values, label='Predicted Data (Future Years)', linestyle='dashed', marker='s')

plt.title('AGRICULTURE, FISHING AND MINING Sector - Energy Consumption Projection')
plt.xlabel('Year')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
df_projectionp = df_percentages

# Extract the years and values for the '   AGRICULTURE, FISHING AND MINING' sector
years = df_projectionp.index.values
values = df_projectionp['   AGRICULTURE, FISHING AND MINING'].values

# Reshape the years array to a 2D array for scikit-learn
years_2d = years.reshape(-1, 1)

# Create a LinearRegression model
model = LinearRegression()

# Fit the model to the data
model.fit(years_2d, values)

# Predict values for the existing years
predicted_values = model.predict(years_2d)

# Predict values for the next 20 years
future_years = np.arange(years[-1] + 1, years[-1] + 21).reshape(-1, 1)
future_predicted_values = model.predict(future_years)

# Print the predicted values for the next 20 years
for year, value in zip(future_years.flatten(), future_predicted_values):
    print(f"Year {year}: Predicted Value {value:.2f}")
# Out:
# Year 2022: Predicted Value 5.73
# Year 2023: Predicted Value 5.72
# Year 2024: Predicted Value 5.70
# Year 2025: Predicted Value 5.68
# Year 2026: Predicted Value 5.66
# Year 2027: Predicted Value 5.65
# Year 2028: Predicted Value 5.63
# Year 2029: Predicted Value 5.61
# Year 2030: Predicted Value 5.59
# Year 2031: Predicted Value 5.58
# Year 2032: Predicted Value 5.56
# Year 2033: Predicted Value 5.54
# Year 2034: Predicted Value 5.52
# Year 2035: Predicted Value 5.51
# Year 2036: Predicted Value 5.49
# Year 2037: Predicted Value 5.47
# Year 2038: Predicted Value 5.45
# Year 2039: Predicted Value 5.44
# Year 2040: Predicted Value 5.42
# Year 2041: Predicted Value 5.40

# %%
# Predict values for the existing years
predicted_values2 = model.predict(years_2d)

# Predict values for the next 20 years
future_years2 = np.arange(years[-1] + 1, years[-1] + 21).reshape(-1, 1)
future_predicted_values2 = model.predict(future_years)

# Create a linear plot
plt.figure(figsize=(10, 6))

# Plot actual data
plt.plot(years, values, label='Actual Data', marker='o')

# Plot predicted data for existing years
plt.plot(years, predicted_values, label='Predicted Data (Existing Years)', marker='x')

# Plot predicted data for future years
plt.plot(future_years2, future_predicted_values2, label='Predicted Data (Future Years)', linestyle='dashed', marker='s')

plt.title('AGRICULTURE, FISHING AND MINING Sector - Energy Percentage Consumption Projection')
plt.xlabel('Year')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA

# Assuming df_projection is your DataFrame containing the data
# Extract the values for the 'AGRICULTURE, FISHING AND MINING' sector
values = df_projection['   AGRICULTURE, FISHING AND MINING'].values

# Fit an ARIMA model
order = (5, 1, 0)  # Replace p, d, q with appropriate values
model = ARIMA(values, order=order)
model_fit = model.fit()

# Predict existing values (for comparison)
predicted_values = model_fit.fittedvalues

# Predict values for the next 20 years
forecast_steps = 20
forecast_values = model_fit.forecast(steps=forecast_steps)

# Create future year indices
future_years = np.arange(df_projection.index[-1] + 1, df_projection.index[-1] + forecast_steps + 1)

# Print the predicted values for the next 20 years
for year, value in zip(future_years, forecast_values):
    print(f"Year {year}: Predicted Value {value:.2f}")
# Out:
# Year 2022: Predicted Value 15368.05
# Year 2023: Predicted Value 15386.00
# Year 2024: Predicted Value 15457.24
# Year 2025: Predicted Value 15475.15
# Year 2026: Predicted Value 15454.73
# Year 2027: Predicted Value 15482.64
# Year 2028: Predicted Value 15495.08
# Year 2029: Predicted Value 15487.33
# Year 2030: Predicted Value 15491.34
# Year 2031: Predicted Value 15500.09
# Year 2032: Predicted Value 15497.52
# Year 2033: Predicted Value 15496.94
# Year 2034: Predicted Value 15500.46
# Year 2035: Predicted Value 15500.61
# Year 2036: Predicted Value 15499.53
# Year 2037: Predicted Value 15500.66
# Year 2038: Predicted Value 15501.19
# Year 2039: Predicted Value 15500.67
# Year 2040: Predicted Value 15500.84
# Year 2041: Predicted Value 15501.21

# %%
# Assuming df_projection is your DataFrame containing the data
# Extract the values for the 'AGRICULTURE, FISHING AND MINING' sector
values = df_projection['   AGRICULTURE, FISHING AND MINING'].values

# Fit an ARIMA model
order = (5, 1, 0)  # Replace p, d, q with appropriate values
model = ARIMA(values, order=order)
model_fit = model.fit()

# Predict existing values (for comparison)
predicted_values = model_fit.fittedvalues

# Predict values for the next 20 years
forecast_steps = 20
future_years = np.arange(df_projection.index[-1] + 1, df_projection.index[-1] + forecast_steps + 1)
forecast_values = model_fit.forecast(steps=forecast_steps)

# Create a linear plot
plt.figure(figsize=(10, 6))

# Plot actual data
plt.plot(df_projection.index, values, label='Actual Data', marker='o')

# Plot predicted data for existing years
plt.plot(df_projection.index, predicted_values, label='Predicted Data (Existing Years)', marker='x')

# Plot predicted data for future years
plt.plot(future_years, forecast_values, label='Predicted Data (Future Years)', linestyle='dashed', marker='s')

plt.title('AGRICULTURE, FISHING AND MINING Sector - Energy Consumption Projection')
plt.xlabel('Year')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA

# Assuming df_projection is your DataFrame containing the data
# Extract the values for the 'AGRICULTURE, FISHING AND MINING' sector
values = df_projectionp['   AGRICULTURE, FISHING AND MINING'].values

# Fit an ARIMA model
order = (5, 1, 0)  # Replace p, d, q with appropriate values
model = ARIMA(values, order=order)
model_fit = model.fit()

# Predict existing values (for comparison)
predicted_values = model_fit.fittedvalues

# Predict values for the next 20 years
forecast_steps = 20
forecast_values = model_fit.forecast(steps=forecast_steps)

# Create future year indices
future_years = np.arange(df_projectionp.index[-1] + 1, df_projectionp.index[-1] + forecast_steps + 1)

# Print the predicted values for the next 20 years
for year, value in zip(future_years, forecast_values):
    print(f"Year {year}: Predicted Value {value:.2f}")
# Out:
# Year 2022: Predicted Value 6.45
# Year 2023: Predicted Value 6.41
# Year 2024: Predicted Value 6.39
# Year 2025: Predicted Value 6.34
# Year 2026: Predicted Value 6.34
# Year 2027: Predicted Value 6.34
# Year 2028: Predicted Value 6.33
# Year 2029: Predicted Value 6.33
# Year 2030: Predicted Value 6.34
# Year 2031: Predicted Value 6.33
# Year 2032: Predicted Value 6.33
# Year 2033: Predicted Value 6.34
# Year 2034: Predicted Value 6.34
# Year 2035: Predicted Value 6.34
# Year 2036: Predicted Value 6.34
# Year 2037: Predicted Value 6.34
# Year 2038: Predicted Value 6.34
# Year 2039: Predicted Value 6.34
# Year 2040: Predicted Value 6.34
# Year 2041: Predicted Value 6.34

# %%
# Assuming df_projection is your DataFrame containing the data
# Extract the values for the 'AGRICULTURE, FISHING AND MINING' sector
values = df_projectionp['   AGRICULTURE, FISHING AND MINING'].values

# Fit an ARIMA model
order = (5, 1, 0)  # Replace p, d, q with appropriate values
model = ARIMA(values, order=order)
model_fit = model.fit()

# Predict existing values (for comparison)
predicted_values = model_fit.fittedvalues

# Predict values for the next 20 years
forecast_steps = 20
future_years = np.arange(df_projectionp.index[-1] + 1, df_projectionp.index[-1] + forecast_steps + 1)
forecast_values = model_fit.forecast(steps=forecast_steps)

# Create a linear plot
plt.figure(figsize=(10, 6))

# Plot actual data
plt.plot(df_projectionp.index, values, label='Actual Data', marker='o')

# Plot predicted data for existing years
plt.plot(df_projectionp.index, predicted_values, label='Predicted Data (Existing Years)', marker='x')

# Plot predicted data for future years
plt.plot(future_years, forecast_values, label='Predicted Data (Future Years)', linestyle='dashed', marker='s')

plt.title('AGRICULTURE, FISHING AND MINING Sector - Energy Consumption Projection')
plt.xlabel('Year')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Assuming df_projection is your DataFrame containing the data
# Extract the values for the 'AGRICULTURE, FISHING AND MINING' sector
values = df_projection['   AGRICULTURE, FISHING AND MINING'].values

# Fit a SARIMAX model
order = (5, 1, 0)  # Replace p, d, q with appropriate values
seasonal_order = (0, 1, 1, 12)  # Replace P, D, Q, S with appropriate seasonal values
model = SARIMAX(values, order=order, seasonal_order=seasonal_order)
model_fit = model.fit()

# Predict existing values (for comparison)
predicted_values = model_fit.fittedvalues

# Predict values for the next 20 years
forecast_steps = 20
forecast_values = model_fit.get_forecast(steps=forecast_steps)

# Create future year indices
future_years = np.arange(df_projection.index[-1] + 1, df_projection.index[-1] + forecast_steps + 1)

# Print the predicted values for the next 20 years
for year, value in zip(future_years, forecast_values.predicted_mean):
    print(f"Year {year}: Predicted Value {value:.2f}")
# Out:
# C:\Users\elsad\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# Year 2022: Predicted Value 15281.46
# Year 2023: Predicted Value 15619.17
# Year 2024: Predicted Value 15864.00
# Year 2025: Predicted Value 16013.88
# Year 2026: Predicted Value 15952.22
# Year 2027: Predicted Value 16320.10
# Year 2028: Predicted Value 16755.36
# Year 2029: Predicted Value 17151.55
# Year 2030: Predicted Value 17561.26
# Year 2031: Predicted Value 17848.21
# Year 2032: Predicted Value 18010.73
# Year 2033: Predicted Value 17842.60
# Year 2034: Predicted Value 17950.98
# Year 2035: Predicted Value 18263.25
# Year 2036: Predicted Value 18383.00
# Year 2037: Predicted Value 18551.21
# Year 2038: Predicted Value 18578.67
# Year 2039: Predicted Value 18859.75
# Year 2040: Predicted Value 19304.16
# ...

# %%
# Assuming df_projection is your DataFrame containing the data
# Extract the values for the 'AGRICULTURE, FISHING AND MINING' sector
values = df_projection['   AGRICULTURE, FISHING AND MINING'].values

# Fit an SARIMAX model
order = (5, 1, 0)  # Replace p, d, q with appropriate values
seasonal_order = (0, 1, 1, 12)  # Replace P, D, Q, S with appropriate seasonal values
model = SARIMAX(values, order=order, seasonal_order=seasonal_order)
model_fit = model.fit()

# Predict existing values (for comparison)
predicted_values = model_fit.fittedvalues

# Predict values for the next 20 years
forecast_steps = 20
future_years = np.arange(df_projection.index[-1] + 1, df_projection.index[-1] + forecast_steps + 1)
forecast_values = model_fit.forecast(steps=forecast_steps)

# Create a linear plot
plt.figure(figsize=(10, 6))

# Plot actual data
plt.plot(df_projection.index, values, label='Actual Data', marker='o')

# Plot predicted data for existing years
plt.plot(df_projection.index, predicted_values, label='Predicted Data (Existing Years)', marker='x')

# Plot predicted data for future years
plt.plot(future_years, forecast_values, label='Predicted Data (Future Years)', linestyle='dashed', marker='s')

plt.title('AGRICULTURE, FISHING AND MINING Sector - Energy Consumption Projection')
plt.xlabel('Year')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\elsad\AppData\Roaming\Python\Python39\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Assuming df_projection is your DataFrame containing the data
# Extract the values for the 'AGRICULTURE, FISHING AND MINING' sector
values = df_projectionp['   AGRICULTURE, FISHING AND MINING'].values

# Fit a SARIMAX model
order = (5, 1, 0)  # Replace p, d, q with appropriate values
seasonal_order = (0, 1, 1, 12)  # Replace P, D, Q, S with appropriate seasonal values
model = SARIMAX(values, order=order, seasonal_order=seasonal_order)
model_fit = model.fit()

# Predict existing values (for comparison)
predicted_values = model_fit.fittedvalues

# Predict values for the next 20 years
forecast_steps = 20
forecast_values = model_fit.get_forecast(steps=forecast_steps)

# Create future year indices
future_years = np.arange(df_projectionp.index[-1] + 1, df_projectionp.index[-1] + forecast_steps + 1)

# Print the predicted values for the next 20 years
for year, value in zip(future_years, forecast_values.predicted_mean):
    print(f"Year {year}: Predicted Value {value:.2f}")
# Out:
# Year 2022: Predicted Value 6.27
# Year 2023: Predicted Value 6.39
# Year 2024: Predicted Value 6.31
# Year 2025: Predicted Value 6.43
# Year 2026: Predicted Value 6.30
# Year 2027: Predicted Value 6.41
# Year 2028: Predicted Value 6.68
# Year 2029: Predicted Value 6.92
# Year 2030: Predicted Value 6.88
# Year 2031: Predicted Value 6.88
# Year 2032: Predicted Value 6.77
# Year 2033: Predicted Value 6.48
# Year 2034: Predicted Value 6.19
# Year 2035: Predicted Value 6.23
# Year 2036: Predicted Value 6.08
# Year 2037: Predicted Value 6.13
# Year 2038: Predicted Value 5.95
# Year 2039: Predicted Value 6.01
# Year 2040: Predicted Value 6.23
# Year 2041: Predicted Value 6.44

# %%
# Assuming df_projection is your DataFrame containing the data
# Extract the values for the 'AGRICULTURE, FISHING AND MINING' sector
values = df_projectionp['   AGRICULTURE, FISHING AND MINING'].values

# Fit an SARIMAX model
order = (5, 1, 0)  # Replace p, d, q with appropriate values
seasonal_order = (0, 1, 1, 12)  # Replace P, D, Q, S with appropriate seasonal values
model = SARIMAX(values, order=order, seasonal_order=seasonal_order)
model_fit = model.fit()

# Predict existing values (for comparison)
predicted_values = model_fit.fittedvalues

# Predict values for the next 20 years
forecast_steps = 20
future_years = np.arange(df_projectionp.index[-1] + 1, df_projectionp.index[-1] + forecast_steps + 1)
forecast_values = model_fit.forecast(steps=forecast_steps)

# Create a linear plot
plt.figure(figsize=(10, 6))

# Plot actual data
plt.plot(df_projectionp.index, values, label='Actual Data', marker='o')

# Plot predicted data for existing years
plt.plot(df_projectionp.index, predicted_values, label='Predicted Data (Existing Years)', marker='x')

# Plot predicted data for future years
plt.plot(future_years, forecast_values, label='Predicted Data (Future Years)', linestyle='dashed', marker='s')

plt.title('AGRICULTURE, FISHING AND MINING Sector - Energy Consumption Projection')
plt.xlabel('Year')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# Assuming df_projection is your DataFrame containing the data
# Extract the values for the 'AGRICULTURE, FISHING AND MINING' sector
values = df_projection['   AGRICULTURE, FISHING AND MINING'].values

# Fit an ETS model
trend = 'add'  # Options: 'add', 'mul', 'additive', 'multiplicative'
seasonal = 'add'  # Options: 'add', 'mul', 'additive', 'multiplicative'
seasonal_periods = 12  # Adjust according to your data's seasonality
model = ExponentialSmoothing(values, trend=trend, seasonal=seasonal, seasonal_periods=seasonal_periods)
model_fit = model.fit()

# Predict existing values (for comparison)
predicted_values = model_fit.fittedvalues

# Predict values for the next 20 years
forecast_steps = 20
forecast_values = model_fit.forecast(steps=forecast_steps)

# Create future year indices
future_years = np.arange(df_projection.index[-1] + 1, df_projection.index[-1] + forecast_steps + 1)

# Print the predicted values for the next 20 years
for year, value in zip(future_years, forecast_values):
    print(f"Year {year}: Predicted Value {value:.2f}")
# Out:
# Year 2022: Predicted Value 15561.44
# Year 2023: Predicted Value 15888.66
# Year 2024: Predicted Value 15978.42
# Year 2025: Predicted Value 16246.68
# Year 2026: Predicted Value 16358.98
# Year 2027: Predicted Value 16632.42
# Year 2028: Predicted Value 17185.40
# Year 2029: Predicted Value 17754.89
# Year 2030: Predicted Value 17903.68
# Year 2031: Predicted Value 18250.85
# Year 2032: Predicted Value 18560.77
# Year 2033: Predicted Value 18372.34
# Year 2034: Predicted Value 18614.35
# Year 2035: Predicted Value 18941.56
# Year 2036: Predicted Value 19031.33
# Year 2037: Predicted Value 19299.59
# Year 2038: Predicted Value 19411.88
# Year 2039: Predicted Value 19685.33
# Year 2040: Predicted Value 20238.30
# Year 2041: Predicted Value 20807.79

# %%
# Assuming df_projection is your DataFrame containing the data
# Extract the values for the 'AGRICULTURE, FISHING AND MINING' sector
values = df_projection['   AGRICULTURE, FISHING AND MINING'].values

# Fit an ETS model
trend = 'add'  # Options: 'add', 'mul', 'additive', 'multiplicative'
seasonal = 'add'  # Options: 'add', 'mul', 'additive', 'multiplicative'
seasonal_periods = 12  # Adjust according to your data's seasonality
model = ExponentialSmoothing(values, trend=trend, seasonal=seasonal, seasonal_periods=seasonal_periods)
model_fit = model.fit()

# Predict existing values (for comparison)
predicted_values = model_fit.fittedvalues

# Predict values for the next 20 years
forecast_steps = 20
forecast_values = model_fit.forecast(steps=forecast_steps)

# Create future year indices
future_years = np.arange(df_projection.index[-1] + 1, df_projection.index[-1] + forecast_steps + 1)

# Create a linear plot
plt.figure(figsize=(10, 6))

# Plot actual data
plt.plot(df_projection.index, values, label='Actual Data', marker='o')

# Plot predicted data for existing years
plt.plot(df_projection.index, predicted_values, label='Predicted Data (Existing Years)', marker='x')

# Plot forecasted data for future years
plt.plot(future_years, forecast_values, label='Forecasted Data (Future Years)', linestyle='dashed', marker='s')

plt.title('AGRICULTURE, FISHING AND MINING Sector - Energy Consumption Projection (ETS)')
plt.xlabel('Year')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# Assuming df_projection is your DataFrame containing the data
# Extract the values for the 'AGRICULTURE, FISHING AND MINING' sector
values = df_projectionp['   AGRICULTURE, FISHING AND MINING'].values

# Fit an ETS model
trend = 'add'  # Options: 'add', 'mul', 'additive', 'multiplicative'
seasonal = 'add'  # Options: 'add', 'mul', 'additive', 'multiplicative'
seasonal_periods = 12  # Adjust according to your data's seasonality
model = ExponentialSmoothing(values, trend=trend, seasonal=seasonal, seasonal_periods=seasonal_periods)
model_fit = model.fit()

# Predict existing values (for comparison)
predicted_values = model_fit.fittedvalues

# Predict values for the next 20 years
forecast_steps = 20
forecast_values = model_fit.forecast(steps=forecast_steps)

# Create future year indices
future_years = np.arange(df_projectionp.index[-1] + 1, df_projectionp.index[-1] + forecast_steps + 1)

# Print the predicted values for the next 20 years
for year, value in zip(future_years, forecast_values):
    print(f"Year {year}: Predicted Value {value:.2f}")
# Out:
# Year 2022: Predicted Value 6.28
# Year 2023: Predicted Value 6.40
# Year 2024: Predicted Value 6.32
# Year 2025: Predicted Value 6.47
# Year 2026: Predicted Value 6.37
# Year 2027: Predicted Value 6.53
# Year 2028: Predicted Value 6.86
# Year 2029: Predicted Value 7.16
# Year 2030: Predicted Value 7.19
# Year 2031: Predicted Value 7.26
# Year 2032: Predicted Value 7.22
# Year 2033: Predicted Value 7.01
# Year 2034: Predicted Value 6.80
# Year 2035: Predicted Value 6.92
# Year 2036: Predicted Value 6.85
# Year 2037: Predicted Value 6.99
# Year 2038: Predicted Value 6.89
# Year 2039: Predicted Value 7.06
# Year 2040: Predicted Value 7.39
# Year 2041: Predicted Value 7.69

# %%
# Assuming df_projection is your DataFrame containing the data
# Extract the values for the 'AGRICULTURE, FISHING AND MINING' sector
values = df_projectionp['   AGRICULTURE, FISHING AND MINING'].values

# Fit an ETS model
trend = 'add'  # Options: 'add', 'mul', 'additive', 'multiplicative'
seasonal = 'add'  # Options: 'add', 'mul', 'additive', 'multiplicative'
seasonal_periods = 12  # Adjust according to your data's seasonality
model = ExponentialSmoothing(values, trend=trend, seasonal=seasonal, seasonal_periods=seasonal_periods)
model_fit = model.fit()

# Predict existing values (for comparison)
predicted_values = model_fit.fittedvalues

# Predict values for the next 20 years
forecast_steps = 20
forecast_values = model_fit.forecast(steps=forecast_steps)

# Create future year indices
future_years = np.arange(df_projectionp.index[-1] + 1, df_projectionp.index[-1] + forecast_steps + 1)

# Create a linear plot
plt.figure(figsize=(10, 6))

# Plot actual data
plt.plot(df_projectionp.index, values, label='Actual Data', marker='o')

# Plot predicted data for existing years
plt.plot(df_projectionp.index, predicted_values, label='Predicted Data (Existing Years)', marker='x')

# Plot forecasted data for future years
plt.plot(future_years, forecast_values, label='Forecasted Data (Future Years)', linestyle='dashed', marker='s')

plt.title('AGRICULTURE, FISHING AND MINING Sector - Energy Consumption Projection (ETS)')
plt.xlabel('Year')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
Dict3=Dict.copy()

for k in Dict3.keys():
   # selected_columns = ['SECTOR', 'OIL', 'NATURAL GAS', 'COAL', 'HYDROENERGY', 'GEOTHERMAL',
    #   'NUCLEAR', 'FIREWOOD', 'SUGARCANE AND PRODUCTS', 'OTHER PRIMARY', 'TOTAL PRIMARIES','Year']
    selected_columns = ['SECTOR', 'NATURAL GAS', 'COAL', 'FIREWOOD','TOTAL PRIMARIES','Year']
    Dict3[k]=Dict3[k][selected_columns]
    selected_rows=['   AGRICULTURE, FISHING AND MINING']
    Dict3[k]=Dict3[k][Dict3[k]['SECTOR'].isin(selected_rows)]
    
    # Concatenate all DataFrames in Dict vertically
    df_conc = pd.concat(Dict3.values(), ignore_index=True)
    
    # Move the column "Year" to the first position
    last_column_name = df_conc.columns[-1]
    # Reorder the columns by concatenating the last column with the rest of the DataFrame
    df_conc = pd.concat([df_conc[last_column_name], df_conc.drop(columns=last_column_name)], axis=1) # Datafames of TOTAL SUPPLY
    df_conc.set_index("Year", inplace=True)
    df_conc.index = df_conc.index.astype(int)
    #df_TC2=df_conc.drop(columns="SECTOR")
    # Set the value "NaN" by Zero
    df_TC2 = df_conc.apply(lambda column: column.fillna(0))
    
# Calculate the percentage of each product relative to 'TOTAL PRIMARIES'
#percentage_columns_2 = ['ELECTRICITY', 'LPG', 'GASOLINE/ALCOHOL', 'KEROSENE/JET FUEL',
 #      'DIESEL OIL', 'FUEL OIL', 'COKE', 'CHARCOAL', 'GASES',
  #     'OTHER SECONDARY', 'NON-ENERGY']
#percentage_columns_2= ['TOTAL PRIMARIES', 'TOTAL SECUNDARIES']

#df_TC2_percentages = (df_TC1[percentage_columns_2].div(df_TC1['TOTAL'], axis=0) * 100).applymap(lambda x: round(x, 2) if isinstance(x, (int, float)) else x)
df_TC2.head()
# Out:
#                                   SECTOR  NATURAL GAS  COAL  FIREWOOD
# Year
# 1970     AGRICULTURE, FISHING AND MINING          0.0   0.0   4900.69  \
# 1971     AGRICULTURE, FISHING AND MINING          0.0   0.0   4710.12
# 1972     AGRICULTURE, FISHING AND MINING          0.0   0.0   4524.19
# 1973     AGRICULTURE, FISHING AND MINING          0.0   0.0   4369.25
# 1974     AGRICULTURE, FISHING AND MINING          0.0   0.0   4183.33
#
#       TOTAL PRIMARIES
# Year
# 1970          4900.69
# 1971          4710.12
# 1972          4524.19
# 1973          4369.25
# 1974          4183.33

# %%
# Drop the 'TOTAL PRIMARIES' column and 'SECTOR' column for calculations
selected_columns_for_percentages = ['NATURAL GAS', 'COAL', 'FIREWOOD']
df_percentages = (df_TC2.drop(columns=['TOTAL PRIMARIES', 'SECTOR'])
                    .div(df_TC2[selected_columns_for_percentages].sum(axis=1), axis=0) * 100)
df_percentages = df_percentages.round(2)

# Print the calculated percentages
df_percentages.head()
# Out:
#       NATURAL GAS  COAL  FIREWOOD
# Year
# 1970          0.0   0.0     100.0
# 1971          0.0   0.0     100.0
# 1972          0.0   0.0     100.0
# 1973          0.0   0.0     100.0
# 1974          0.0   0.0     100.0

# %%
df_percentages = (df_TC2.drop(columns=['NATURAL GAS', 'COAL', 'FIREWOOD', 'SECTOR'])
                    .div(df_EC['FINAL CONSUMPTION'].sum(axis=0), axis=0) * 100)
df_percentages = df_percentages.round(2)

# Print the calculated percentages
df_percentages.head()
# Out:
#       TOTAL PRIMARIES
# Year
# 1970             0.06
# 1971             0.06
# 1972             0.06
# 1973             0.06
# 1974             0.06

# %%
Dict3=Dict.copy()

for k in Dict3.keys():
   # selected_columns = ['SECTOR', 'OIL', 'NATURAL GAS', 'COAL', 'HYDROENERGY', 'GEOTHERMAL',
    #   'NUCLEAR', 'FIREWOOD', 'SUGARCANE AND PRODUCTS', 'OTHER PRIMARY', 'TOTAL PRIMARIES','Year']
    selected_columns = ['SECTOR','ELECTRICITY', 'LPG', 'GASOLINE/ALCOHOL',
       'KEROSENE/JET FUEL', 'DIESEL OIL', 'FUEL OIL', 'COKE', 'CHARCOAL', 'OTHER SECONDARY', 'TOTAL SECUNDARIES', 'Year']
    Dict3[k]=Dict3[k][selected_columns]
    selected_rows=['   AGRICULTURE, FISHING AND MINING']
    Dict3[k]=Dict3[k][Dict3[k]['SECTOR'].isin(selected_rows)]
    
    # Concatenate all DataFrames in Dict vertically
    df_conc = pd.concat(Dict3.values(), ignore_index=True)
    
    # Move the column "Year" to the first position
    last_column_name = df_conc.columns[-1]
    # Reorder the columns by concatenating the last column with the rest of the DataFrame
    df_conc = pd.concat([df_conc[last_column_name], df_conc.drop(columns=last_column_name)], axis=1) # Datafames of TOTAL SUPPLY
    df_conc.set_index("Year", inplace=True)
    df_conc.index = df_conc.index.astype(int)
    #df_TC2=df_conc.drop(columns="SECTOR")
    # Set the value "NaN" by Zero
    df_TC3 = df_conc.apply(lambda column: column.fillna(0))
    
# Calculate the percentage of each product relative to 'TOTAL PRIMARIES'
#percentage_columns_2 = ['ELECTRICITY', 'LPG', 'GASOLINE/ALCOHOL', 'KEROSENE/JET FUEL',
 #      'DIESEL OIL', 'FUEL OIL', 'COKE', 'CHARCOAL', 'GASES',
  #     'OTHER SECONDARY', 'NON-ENERGY']
#percentage_columns_2= ['TOTAL PRIMARIES', 'TOTAL SECUNDARIES']

#df_TC2_percentages = (df_TC1[percentage_columns_2].div(df_TC1['TOTAL'], axis=0) * 100).applymap(lambda x: round(x, 2) if isinstance(x, (int, float)) else x)
df_TC3.head()
# Out:
#                                   SECTOR  ELECTRICITY  LPG  GASOLINE/ALCOHOL
# Year
# 1970     AGRICULTURE, FISHING AND MINING        27.25  0.0               0.0  \
# 1971     AGRICULTURE, FISHING AND MINING        33.35  0.0               0.0
# 1972     AGRICULTURE, FISHING AND MINING        38.60  0.0               0.0
# 1973     AGRICULTURE, FISHING AND MINING        45.39  0.0               0.0
# 1974     AGRICULTURE, FISHING AND MINING        56.31  0.0               0.0
#
#       KEROSENE/JET FUEL  DIESEL OIL  FUEL OIL  COKE  CHARCOAL
# Year
# 1970                0.0      392.65     11.05   0.0     19.37  \
# 1971                0.0      531.54     23.01   0.0     19.37
# 1972                0.0      711.58     46.02   0.0     18.08
# 1973                0.0      936.20     73.64   0.0     17.44
# 1974                0.0     1035.64     85.60   0.0     15.50
#
#       OTHER SECONDARY  TOTAL SECUNDARIES
# Year
# 1970              0.0             450.32
# ...

# %%
# Drop the 'TOTAL PRIMARIES' column and 'SECTOR' column for calculations
selected_columns_for_percentages = ['ELECTRICITY', 'LPG', 'GASOLINE/ALCOHOL',
       'KEROSENE/JET FUEL', 'DIESEL OIL', 'FUEL OIL', 'COKE', 'CHARCOAL', 'OTHER SECONDARY']
df_percentages = (df_TC3.drop(columns=['TOTAL SECUNDARIES', 'SECTOR'])
                    .div(df_TC3[selected_columns_for_percentages].sum(axis=1), axis=0) * 100)
df_percentages = df_percentages.round(2)

# Print the calculated percentages
df_percentages.head()
# Out:
#       ELECTRICITY  LPG  GASOLINE/ALCOHOL  KEROSENE/JET FUEL  DIESEL OIL
# Year
# 1970         6.05  0.0               0.0                0.0       87.19  \
# 1971         5.49  0.0               0.0                0.0       87.53
# 1972         4.74  0.0               0.0                0.0       87.39
# 1973         4.23  0.0               0.0                0.0       87.28
# 1974         4.72  0.0               0.0                0.0       86.81
#
#       FUEL OIL  COKE  CHARCOAL  OTHER SECONDARY
# Year
# 1970      2.45   0.0      4.30              0.0
# 1971      3.79   0.0      3.19              0.0
# 1972      5.65   0.0      2.22              0.0
# 1973      6.87   0.0      1.63              0.0
# 1974      7.17   0.0      1.30              0.0

# %%
df_percentages = (df_TC3.drop(columns=['ELECTRICITY', 'LPG', 'GASOLINE/ALCOHOL',
       'KEROSENE/JET FUEL', 'DIESEL OIL', 'FUEL OIL', 'COKE', 'CHARCOAL', 'OTHER SECONDARY', 'SECTOR'])
                    .div(df_EC['FINAL CONSUMPTION'].sum(axis=0), axis=0) * 100)
df_percentages = df_percentages.round(2)

# Print the calculated percentages
df2_percentages.head()
# Out:
#       TOTAL SECUNDARIES
# Year
# 1970               0.01
# 1971               0.01
# 1972               0.01
# 1973               0.01
# 1974               0.02

# %%
# Drop the 'TOTAL PRIMARIES' column (if not already dropped) as it is not needed for the stack plot
df_stackplot = df_TC2.drop(columns=['TOTAL PRIMARIES', 'SECTOR'])

# Plot both stack plots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))


df_stackplot.plot.area(stacked=True, alpha=0.7, ax=ax1)
ax1.set_xlabel('Year')
ax1.set_ylabel('Final Consumption')
ax1.set_title('Energy Consumption Over the Years')
ax1.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0))

df_percentages.plot.area(stacked=True, alpha=0.7, ax=ax2)

ax2.set_xlabel('Year')
ax2.set_ylabel(' Final Consumption  (%)')
ax2.set_title('Percentage of  Energy Consumption Over the Years')
ax2.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0))

plt.tight_layout()
plt.show()

# %%
# Drop the 'TOTAL PRIMARIES' column (if not already dropped) as it is not needed for the stack plot
df_stackplot = df_TC3.drop(columns=['TOTAL SECUNDARIES', 'SECTOR'])

# Plot both stack plots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))


df_stackplot.plot.area(stacked=True, alpha=0.7, ax=ax1)
ax1.set_xlabel('Year')
ax1.set_ylabel('Final Consumption')
ax1.set_title('Energy Consumption Over the Years')
ax1.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0))

df_percentages.plot.area(stacked=True, alpha=0.7, ax=ax2)

ax2.set_xlabel('Year')
ax2.set_ylabel(' Final Consumption  (%)')
ax2.set_title('Percentage of  Energy Consumption Over the Years')
ax2.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0))

plt.tight_layout()
plt.show()
